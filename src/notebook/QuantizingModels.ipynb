# %%
# Import library
import numpy as np
import torch.nn as nn, torch
import matplotlib.pyplot as plt
import sys
from tqdm import tqdm
from sklearn.metrics import classification_report

# Adding path to py files
sys.path.append('..')

# %% [markdown]
# # **QUANTIZATION ONLY**

# %%
# Importing the custom quantization module
from CustomQuantization_tensor import CustomQuantization as quant
from convertQuantizeModel_tensor import convertDenseLayer
from utils_tensor import *

# %% [markdown]
# ## **T5 SMALL PRETRAINED MODEL**

# %% [markdown]
# ### **DOWNLOADING AND SAVING T5 SMALL MODEL**

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

# Define the model name
t5_model_name = 'google-t5/t5-small'

# T5 small Model
t5_tokenizer = T5Tokenizer.from_pretrained(t5_model_name)
t5_model = T5ForConditionalGeneration.from_pretrained(t5_model_name)

# Saving the orginal pretrained model
torch.save(t5_model, f"../../saved/{t5_model_name}.pt")
del t5_model
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %% [markdown]
# ### **LOADING A COPY OF PRETRAINED MODEL AND QUANTIZING**

# %%
t5_small_model_copy = torch.load(f"../../saved/{t5_model_name}.pt")
Quant_t5_small_model = convertDenseLayer(t5_small_model_copy)
# Out:
# Layer Name: q
# Local minimum:  tensor(-0.3770)  Local max:  tensor(0.4395) Points:  500
# Ratio of first region range coverage: tensor(0.3373) Region of selection index:  2
# Ratio of second region range coverage: tensor(0.2149) Region of selection index:  3
# First Region Range:  (tensor(-0.2951), tensor(-0.0203))
# Second Region Range (tensor(0.0124), tensor(0.1875))
# Layer Name: k
# Local minimum:  tensor(-3.5000)  Local max:  tensor(4.) Points:  500
# Ratio of first region range coverage: tensor(0.2771) Region of selection index:  0
# Ratio of second region range coverage: tensor(0.1727) Region of selection index:  1
# First Region Range:  (tensor(-2.4329), tensor(-0.3587))
# Second Region Range (tensor(0.0170), tensor(1.3096))
# Layer Name: v
# Local minimum:  tensor(-2.8750)  Local max:  tensor(2.3281) Points:  500
# Ratio of first region range coverage: tensor(0.2771) Region of selection index:  0
# Ratio of second region range coverage: tensor(0.1968) Region of selection index:  1
# First Region Range:  (tensor(-1.8531), tensor(-0.4142))
# Second Region Range (tensor(0.0654), tensor(1.0873))
# Layer Name: o
# Local minimum:  tensor(-9.6875)  Local max:  tensor(12.5625) Points:  500
# Ratio of first region range coverage: tensor(0.2289) Region of selection index:  4
# Ratio of second region range coverage: tensor(0.0643) Region of selection index:  0
# First Region Range:  (tensor(-8.5728), tensor(-7.1459))
# Second Region Range (tensor(-3.1329), tensor(1.9503))
# Layer Name: wi
# Local minimum:  tensor(-16.6250)  Local max:  tensor(14.5000) Points:  500
# Ratio of first region range coverage: tensor(0.1807) Region of selection index:  5
# Ratio of second region range coverage: tensor(0.0643) Region of selection index:  3
# First Region Range:  (tensor(-5.7094), tensor(-3.7134))
# Second Region Range (tensor(-3.3392), tensor(2.2745))
# Layer Name: wo
# Local minimum:  tensor(-8.1875)  Local max:  tensor(8.9375) Points:  500
# Ratio of first region range coverage: tensor(0.2309) Region of selection index:  5
# Ratio of second region range coverage: tensor(0.1225) Region of selection index:  0
# First Region Range:  (tensor(-7.5698), tensor(-5.4763))
# Second Region Range (tensor(-2.6622), tensor(1.2844))
# Layer Name: q
# Local minimum:  tensor(-0.3926)  Local max:  tensor(0.4922) Points:  500
# Ratio of first region range coverage: tensor(0.2550) Region of selection index:  1
# Ratio of second region range coverage: tensor(0.1847) Region of selection index:  2
# First Region Range:  (tensor(-0.2596), tensor(-0.0344))
# Second Region Range (tensor(0.0081), tensor(0.1713))
# Layer Name: k
# Local minimum:  tensor(-3.1719)  Local max:  tensor(2.7188) Points:  500
# Ratio of first region range coverage: tensor(0.2631) Region of selection index:  3
# Ratio of second region range coverage: tensor(0.2249) Region of selection index:  4
# First Region Range:  (tensor(-1.9560), tensor(-0.4095))
# Second Region Range (tensor(0.0745), tensor(1.3966))
# Layer Name: v
# Local minimum:  tensor(-3.5000)  Local max:  tensor(3.2812) Points:  500
# Ratio of first region range coverage: tensor(0.3112) Region of selection index:  1
# Ratio of second region range coverage: tensor(0.2088) Region of selection index:  2
# First Region Range:  (tensor(-2.5351), tensor(-0.4287))
# Second Region Range (tensor(0.0877), tensor(1.5010))
# Layer Name: o
# Local minimum:  tensor(-12.8750)  Local max:  tensor(12.8750) Points:  500
# Ratio of first region range coverage: tensor(0.3213) Region of selection index:  4
# Ratio of second region range coverage: tensor(0.0743) Region of selection index:  1
# First Region Range:  (tensor(-8.4887), tensor(-6.5794))
# Second Region Range (tensor(-4.6701), tensor(3.5864))
# Layer Name: wi
# Local minimum:  tensor(-16.7500)  Local max:  tensor(19.6250) Points:  500
# Ratio of first region range coverage: tensor(0.2008) Region of selection index:  13
# Ratio of second region range coverage: tensor(0.0723) Region of selection index:  2
# First Region Range:  (tensor(-13.6884), tensor(-11.0641))
# Second Region Range (tensor(-3.6288), tensor(3.6608))
# Layer Name: wo
# Local minimum:  tensor(-9.5000)  Local max:  tensor(15.) Points:  500
# Ratio of first region range coverage: tensor(0.1867) Region of selection index:  5
# Ratio of second region range coverage: tensor(0.0100) Region of selection index:  1
# First Region Range:  (tensor(-3.6082), tensor(-3.3627))
# Second Region Range (tensor(-2.6263), tensor(1.9399))
# Layer Name: q
# Local minimum:  tensor(-0.4023)  Local max:  tensor(0.3750) Points:  500
# Ratio of first region range coverage: tensor(0.2410) Region of selection index:  1
# Ratio of second region range coverage: tensor(0.0743) Region of selection index:  2
# First Region Range:  (tensor(-0.1905), tensor(-0.0035))
# Second Region Range (tensor(0.0728), tensor(0.1304))
# Layer Name: k
# Local minimum:  tensor(-3.7656)  Local max:  tensor(2.5781) Points:  500
# Ratio of first region range coverage: tensor(0.2289) Region of selection index:  0
# Ratio of second region range coverage: tensor(0.1627) Region of selection index:  1
# First Region Range:  (tensor(-1.6680), tensor(-0.2187))
# Second Region Range (tensor(0.0101), tensor(1.0399))
# Layer Name: v
# Local minimum:  tensor(-4.1250)  Local max:  tensor(5.1875) Points:  500
# Ratio of first region range coverage: tensor(0.2610) Region of selection index:  0
# Ratio of second region range coverage: tensor(0.1988) Region of selection index:  1
# First Region Range:  (tensor(-2.8933), tensor(-0.4672))
# Second Region Range (tensor(0.0740), tensor(1.9216))
# Layer Name: o
# Local minimum:  tensor(-9.8125)  Local max:  tensor(11.1250) Points:  500
# Ratio of first region range coverage: tensor(0.3635) Region of selection index:  4
# Ratio of second region range coverage: tensor(0.0482) Region of selection index:  0
# First Region Range:  (tensor(-7.1691), tensor(-6.1621))
# Second Region Range (tensor(-4.2320), tensor(3.3626))
# Layer Name: wi
# Local minimum:  tensor(-25.)  Local max:  tensor(34.5000) Points:  500
# Ratio of first region range coverage: tensor(0.1667) Region of selection index:  4
# Ratio of second region range coverage: tensor(0.0703) Region of selection index:  0
# First Region Range:  (tensor(-11.2876), tensor(-7.1142))
# Second Region Range (tensor(-5.3257), tensor(4.5711))
# Layer Name: wo
# Local minimum:  tensor(-11.5625)  Local max:  tensor(7.3125) Points:  500
# Ratio of first region range coverage: tensor(0.2711) Region of selection index:  2
# Ratio of second region range coverage: tensor(0.0100) Region of selection index:  1
# First Region Range:  (tensor(-4.1487), tensor(-3.9595))
# Second Region Range (tensor(-3.0139), tensor(2.0926))
# Layer Name: q
# Local minimum:  tensor(-0.3906)  Local max:  tensor(0.3750) Points:  500
# Ratio of first region range coverage: tensor(0.2631) Region of selection index:  2
# Ratio of second region range coverage: tensor(0.1968) Region of selection index:  3
# First Region Range:  (tensor(-0.2357), tensor(-0.0347))
# Second Region Range (tensor(0.0083), tensor(0.1587))
# Layer Name: k
# Local minimum:  tensor(-2.9219)  Local max:  tensor(2.7812) Points:  500
# Ratio of first region range coverage: tensor(0.2771) Region of selection index:  3
# Ratio of second region range coverage: tensor(0.2068) Region of selection index:  4
# First Region Range:  (tensor(-1.9275), tensor(-0.3503))
# Second Region Range (tensor(0.0611), tensor(1.2383))
# Layer Name: v
# Local minimum:  tensor(-3.4531)  Local max:  tensor(3.7500) Points:  500
# Ratio of first region range coverage: tensor(0.3916) Region of selection index:  1
# Ratio of second region range coverage: tensor(0.1084) Region of selection index:  2
# First Region Range:  (tensor(-2.9623), tensor(-0.1475))
# Second Region Range (tensor(0.7186), tensor(1.4981))
# Layer Name: o
# Local minimum:  tensor(-16.3750)  Local max:  tensor(13.8125) Points:  500
# Ratio of first region range coverage: tensor(0.3755) Region of selection index:  1
# Ratio of second region range coverage: tensor(0.0602) Region of selection index:  0
# First Region Range:  (tensor(-8.8130), tensor(-6.9981))
# Second Region Range (tensor(-6.6351), tensor(4.6776))
# Layer Name: wi
# Local minimum:  tensor(-15.3125)  Local max:  tensor(18.8750) Points:  500
# Ratio of first region range coverage: tensor(0.2149) Region of selection index:  5
# Ratio of second region range coverage: tensor(0.0482) Region of selection index:  4
# First Region Range:  (tensor(-6.2004), tensor(-4.5561))
# Second Region Range (tensor(-4.1450), tensor(3.1857))
# Layer Name: wo
# Local minimum:  tensor(-14.5625)  Local max:  tensor(14.7500) Points:  500
# Ratio of first region range coverage: tensor(0.1767) Region of selection index:  6
# Ratio of second region range coverage: tensor(0.0402) Region of selection index:  0
# First Region Range:  (tensor(-14.5625), tensor(-13.3877))
# Second Region Range (tensor(-3.1077), tensor(2.0616))
# Layer Name: q
# Local minimum:  tensor(-0.5586)  Local max:  tensor(0.6484) Points:  500
# Ratio of first region range coverage: tensor(0.2149) Region of selection index:  0
# Ratio of second region range coverage: tensor(0.1365) Region of selection index:  1
# First Region Range:  (tensor(-0.2828), tensor(-0.0240))
# Second Region Range (tensor(-0.0071), tensor(0.1574))
# Layer Name: k
# Local minimum:  tensor(-4.3750)  Local max:  tensor(4.3750) Points:  500
# Ratio of first region range coverage: tensor(0.2631) Region of selection index:  0
# Ratio of second region range coverage: tensor(0.1546) Region of selection index:  1
# First Region Range:  (tensor(-2.6215), tensor(-0.3244))
# Second Region Range (tensor(0.0088), tensor(1.3590))
# Layer Name: v
# Local minimum:  tensor(-4.1875)  Local max:  tensor(4.0625) Points:  500
# Ratio of first region range coverage: tensor(0.3052) Region of selection index:  1
# Ratio of second region range coverage: tensor(0.2068) Region of selection index:  2
# First Region Range:  (tensor(-3.1294), tensor(-0.6164))
# Second Region Range (tensor(0.0946), tensor(1.7975))
# Layer Name: o
# Local minimum:  tensor(-18.6250)  Local max:  tensor(14.6875) Points:  500
# Ratio of first region range coverage: tensor(0.3173) Region of selection index:  1
# Ratio of second region range coverage: tensor(0.1124) Region of selection index:  4
# First Region Range:  (tensor(-10.4137), tensor(0.1341))
# Second Region Range (tensor(2.6042), tensor(6.3427))
# Layer Name: wi
# Local minimum:  tensor(-27.1250)  Local max:  tensor(30.2500) Points:  500
# Ratio of first region range coverage: tensor(0.1928) Region of selection index:  3
# Ratio of second region range coverage: tensor(0.0020) Region of selection index:  2
# First Region Range:  (tensor(-8.1533), tensor(-8.0383))
# Second Region Range (tensor(-7.3484), tensor(3.6896))
# Layer Name: wo
# Local minimum:  tensor(-13.4375)  Local max:  tensor(16.7500) Points:  500
# Ratio of first region range coverage: tensor(0.2490) Region of selection index:  2
# Ratio of second region range coverage: tensor(0.0622) Region of selection index:  0
# First Region Range:  (tensor(-8.2953), tensor(-6.4200))
# Second Region Range (tensor(-4.8471), tensor(2.6544))
# Layer Name: q
# Local minimum:  tensor(-0.4824)  Local max:  tensor(0.5547) Points:  500
# Ratio of first region range coverage: tensor(0.2410) Region of selection index:  0
# Ratio of second region range coverage: tensor(0.1044) Region of selection index:  2
# First Region Range:  (tensor(-0.2496), tensor(-0.0002))
# Second Region Range (tensor(0.0268), tensor(0.1349))
# Layer Name: k
# Local minimum:  tensor(-3.4375)  Local max:  tensor(3.7969) Points:  500
# Ratio of first region range coverage: tensor(0.3133) Region of selection index:  1
# Ratio of second region range coverage: tensor(0.1566) Region of selection index:  2
# First Region Range:  (tensor(-2.5676), tensor(-0.3060))
# Second Region Range (tensor(0.0130), tensor(1.1438))
# Layer Name: v
# Local minimum:  tensor(-5.0625)  Local max:  tensor(5.2500) Points:  500
# Ratio of first region range coverage: tensor(0.3494) Region of selection index:  2
# Ratio of second region range coverage: tensor(0.1827) Region of selection index:  3
# First Region Range:  (tensor(-3.9465), tensor(-0.3506))
# Second Region Range (tensor(0.3727), tensor(2.2534))
# Layer Name: o
# Local minimum:  tensor(-20.8750)  Local max:  tensor(22.8750) Points:  500
# Ratio of first region range coverage: tensor(0.2851) Region of selection index:  1
# Ratio of second region range coverage: tensor(0.2129) Region of selection index:  3
# First Region Range:  (tensor(-13.5103), tensor(-1.0604))
# Second Region Range (tensor(-0.6220), tensor(8.6716))
# Layer Name: wi
# Local minimum:  tensor(-68.5000)  Local max:  tensor(51.7500) Points:  500
# Ratio of first region range coverage: tensor(0.1586) Region of selection index:  4
# Ratio of second region range coverage: tensor(0.0904) Region of selection index:  0
# First Region Range:  (tensor(-32.3527), tensor(-21.5085))
# Second Region Range (tensor(-13.7971), tensor(5.2405))
# Layer Name: wo
# Local minimum:  tensor(-12.5000)  Local max:  tensor(11.1875) Points:  500
# Ratio of first region range coverage: tensor(0.3153) Region of selection index:  6
# Ratio of second region range coverage: tensor(0.0482) Region of selection index:  2
# First Region Range:  (tensor(-9.9841), tensor(-8.8448))
# Second Region Range (tensor(-4.6675), tensor(2.7853))
# Layer Name: q
# Local minimum:  tensor(-0.5117)  Local max:  tensor(0.5312) Points:  500
# Ratio of first region range coverage: tensor(0.2751) Region of selection index:  2
# Ratio of second region range coverage: tensor(0.1406) Region of selection index:  3
# First Region Range:  (tensor(-0.2985), tensor(-0.0122))
# Second Region Range (tensor(0.0505), tensor(0.1968))
# Layer Name: k
# Local minimum:  tensor(-3.9844)  Local max:  tensor(3.6719) Points:  500
# Ratio of first region range coverage: tensor(0.3012) Region of selection index:  2
# Ratio of second region range coverage: tensor(0.1446) Region of selection index:  3
# First Region Range:  (tensor(-2.4194), tensor(-0.1179))
# Second Region Range (tensor(0.3117), tensor(1.4164))
# Layer Name: v
# Local minimum:  tensor(-2.4531)  Local max:  tensor(2.3906) Points:  500
# Ratio of first region range coverage: tensor(0.3896) Region of selection index:  1
# Ratio of second region range coverage: tensor(0.2289) Region of selection index:  2
# First Region Range:  (tensor(-2.2007), tensor(-0.3176))
# Second Region Range (tensor(0.1192), tensor(1.2258))
# Layer Name: o
# Local minimum:  tensor(-12.5625)  Local max:  tensor(13.7500) Points:  500
# Ratio of first region range coverage: tensor(0.2490) Region of selection index:  5
# Ratio of second region range coverage: tensor(0.1265) Region of selection index:  4
# First Region Range:  (tensor(-6.7621), tensor(-3.4401))
# Second Region Range (tensor(-3.0183), tensor(3.5203))
# Layer Name: q
# Local minimum:  tensor(-0.3438)  Local max:  tensor(0.3066) Points:  500
# Ratio of first region range coverage: tensor(0.3876) Region of selection index:  2
# Ratio of second region range coverage: tensor(0.1566) Region of selection index:  3
# First Region Range:  (tensor(-0.2603), tensor(-0.0088))
# Second Region Range (tensor(0.0720), tensor(0.1737))
# Layer Name: k
# Local minimum:  tensor(-4.0312)  Local max:  tensor(2.9219) Points:  500
# Ratio of first region range coverage: tensor(0.2892) Region of selection index:  0
# Ratio of second region range coverage: tensor(0.1667) Region of selection index:  1
# First Region Range:  (tensor(-2.2895), tensor(-0.2830))
# Second Region Range (tensor(0.0375), tensor(1.1940))
# Layer Name: v
# Local minimum:  tensor(-2.5625)  Local max:  tensor(2.2812) Points:  500
# Ratio of first region range coverage: tensor(0.3775) Region of selection index:  0
# Ratio of second region range coverage: tensor(0.2550) Region of selection index:  1
# First Region Range:  (tensor(-2.1354), tensor(-0.3105))
# Second Region Range (tensor(0.0778), tensor(1.3106))
# Layer Name: o
# Local minimum:  tensor(-12.1250)  Local max:  tensor(14.0625) Points:  500
# Ratio of first region range coverage: tensor(0.2249) Region of selection index:  3
# Ratio of second region range coverage: tensor(0.2169) Region of selection index:  2
# First Region Range:  (tensor(-9.9208), tensor(-4.2530))
# Second Region Range (tensor(-2.8885), tensor(2.9892))
# Layer Name: wi
# Local minimum:  tensor(-15.7500)  Local max:  tensor(14.5625) Points:  500
# Ratio of first region range coverage: tensor(0.1687) Region of selection index:  7
# Ratio of second region range coverage: tensor(0.0602) Region of selection index:  6
# First Region Range:  (tensor(-5.0586), tensor(-3.2362))
# Second Region Range (tensor(-2.5680), tensor(2.5347))
# Layer Name: wo
# Local minimum:  tensor(-10.1875)  Local max:  tensor(7.3750) Points:  500
# Ratio of first region range coverage: tensor(0.2209) Region of selection index:  4
# Ratio of second region range coverage: tensor(0.0482) Region of selection index:  0
# First Region Range:  (tensor(-5.3305), tensor(-4.4858))
# Second Region Range (tensor(-2.2685), tensor(1.6030))
# Layer Name: q
# Local minimum:  tensor(-0.3281)  Local max:  tensor(0.3379) Points:  500
# Ratio of first region range coverage: tensor(0.3193) Region of selection index:  1
# Ratio of second region range coverage: tensor(0.2329) Region of selection index:  2
# First Region Range:  (tensor(-0.2507), tensor(-0.0385))
# Second Region Range (tensor(0.0056), tensor(0.1604))
# Layer Name: k
# Local minimum:  tensor(-2.6250)  Local max:  tensor(2.4844) Points:  500
# Ratio of first region range coverage: tensor(0.3554) Region of selection index:  0
# Ratio of second region range coverage: tensor(0.1285) Region of selection index:  1
# First Region Range:  (tensor(-1.9287), tensor(-0.1164))
# Second Region Range (tensor(0.3546), tensor(1.0099))
# Layer Name: v
# Local minimum:  tensor(-3.9844)  Local max:  tensor(3.8125) Points:  500
# Ratio of first region range coverage: tensor(0.3976) Region of selection index:  0
# Ratio of second region range coverage: tensor(0.0161) Region of selection index:  1
# First Region Range:  (tensor(-3.1406), tensor(-0.0469))
# Second Region Range (tensor(1.5781), tensor(1.7031))
# Layer Name: o
# Local minimum:  tensor(-17.)  Local max:  tensor(14.6875) Points:  500
# Ratio of first region range coverage: tensor(0.4137) Region of selection index:  5
# Ratio of second region range coverage: tensor(0.0060) Region of selection index:  1
# First Region Range:  (tensor(-8.9987), tensor(-8.8082))
# Second Region Range (tensor(-6.7762), tensor(6.3052))
# Layer Name: q
# Local minimum:  tensor(-0.4375)  Local max:  tensor(0.4199) Points:  500
# Ratio of first region range coverage: tensor(0.3193) Region of selection index:  1
# Ratio of second region range coverage: tensor(0.2189) Region of selection index:  2
# First Region Range:  (tensor(-0.3207), tensor(-0.0475))
# Second Region Range (tensor(0.0110), tensor(0.1983))
# Layer Name: k
# Local minimum:  tensor(-5.1250)  Local max:  tensor(4.8438) Points:  500
# Ratio of first region range coverage: tensor(0.2129) Region of selection index:  3
# Ratio of second region range coverage: tensor(0.1606) Region of selection index:  4
# First Region Range:  (tensor(-2.2482), tensor(-0.1306))
# Second Region Range (tensor(-0.0907), tensor(1.5075))
# Layer Name: v
# Local minimum:  tensor(-3.1875)  Local max:  tensor(3.5312) Points:  500
# Ratio of first region range coverage: tensor(0.4197) Region of selection index:  0
# Ratio of second region range coverage: tensor(0.2129) Region of selection index:  4
# First Region Range:  (tensor(-3.1202), tensor(-0.3061))
# Second Region Range (tensor(0.3402), tensor(1.7674))
# Layer Name: o
# Local minimum:  tensor(-7.5000)  Local max:  tensor(6.9688) Points:  500
# Ratio of first region range coverage: tensor(0.3153) Region of selection index:  7
# Ratio of second region range coverage: tensor(0.0442) Region of selection index:  0
# First Region Range:  (tensor(-7.5000), tensor(-6.8621))
# Second Region Range (tensor(-2.6288), tensor(1.9235))
# Layer Name: wi
# Local minimum:  tensor(-18.2500)  Local max:  tensor(25.2500) Points:  500
# Ratio of first region range coverage: tensor(0.1707) Region of selection index:  4
# Ratio of second region range coverage: tensor(0.0261) Region of selection index:  1
# First Region Range:  (tensor(-6.8302), tensor(-5.6969))
# Second Region Range (tensor(-4.4765), tensor(2.9334))
# Layer Name: wo
# Local minimum:  tensor(-15.8125)  Local max:  tensor(14.6250) Points:  500
# Ratio of first region range coverage: tensor(0.1506) Region of selection index:  4
# Ratio of second region range coverage: tensor(0.0482) Region of selection index:  1
# First Region Range:  (tensor(-8.8588), tensor(-7.3949))
# Second Region Range (tensor(-2.8811), tensor(1.6936))
# Layer Name: q
# Local minimum:  tensor(-0.4102)  Local max:  tensor(0.5000) Points:  500
# Ratio of first region range coverage: tensor(0.2068) Region of selection index:  1
# Ratio of second region range coverage: tensor(0.1486) Region of selection index:  2
# First Region Range:  (tensor(-0.2186), tensor(-0.0308))
# Second Region Range (tensor(0.0039), tensor(0.1389))
# Layer Name: k
# Local minimum:  tensor(-3.2500)  Local max:  tensor(3.0625) Points:  500
# Ratio of first region range coverage: tensor(0.2671) Region of selection index:  1
# Ratio of second region range coverage: tensor(0.2068) Region of selection index:  2
# First Region Range:  (tensor(-1.9217), tensor(-0.2392))
# Second Region Range (tensor(0.0391), tensor(1.3421))
# Layer Name: v
# Local minimum:  tensor(-5.4062)  Local max:  tensor(4.7188) Points:  500
# Ratio of first region range coverage: tensor(0.3353) Region of selection index:  0
# Ratio of second region range coverage: tensor(0.2048) Region of selection index:  1
# First Region Range:  (tensor(-4.1077), tensor(-0.7191))
# Second Region Range (tensor(0.0925), tensor(2.1621))
# Layer Name: o
# Local minimum:  tensor(-19.1250)  Local max:  tensor(23.3750) Points:  500
# Ratio of first region range coverage: tensor(0.2610) Region of selection index:  6
# Ratio of second region range coverage: tensor(0.0482) Region of selection index:  0
# First Region Range:  (tensor(-18.2733), tensor(-16.2292))
# Second Region Range (tensor(-6.0088), tensor(5.0634))
# Layer Name: q
# Local minimum:  tensor(-0.3652)  Local max:  tensor(0.4609) Points:  500
# Ratio of first region range coverage: tensor(0.3313) Region of selection index:  0
# Ratio of second region range coverage: tensor(0.2149) Region of selection index:  2
# First Region Range:  (tensor(-0.3172), tensor(-0.0440))
# Second Region Range (tensor(0.0205), tensor(0.1977))
# Layer Name: k
# Local minimum:  tensor(-5.8125)  Local max:  tensor(5.4688) Points:  500
# Ratio of first region range coverage: tensor(0.1566) Region of selection index:  3
# Ratio of second region range coverage: tensor(0.1526) Region of selection index:  4
# First Region Range:  (tensor(-2.0144), tensor(-0.2510))
# Second Region Range (tensor(-0.0475), tensor(1.6707))
# Layer Name: v
# Local minimum:  tensor(-3.7500)  Local max:  tensor(3.7344) Points:  500
# Ratio of first region range coverage: tensor(0.3855) Region of selection index:  0
# Ratio of second region range coverage: tensor(0.2108) Region of selection index:  1
# First Region Range:  (tensor(-3.4200), tensor(-0.5403))
# Second Region Range (tensor(0.2397), tensor(1.8145))
# Layer Name: o
# Local minimum:  tensor(-9.3125)  Local max:  tensor(9.3750) Points:  500
# Ratio of first region range coverage: tensor(0.1847) Region of selection index:  3
# Ratio of second region range coverage: tensor(0.1305) Region of selection index:  4
# First Region Range:  (tensor(-3.8448), tensor(-0.3994))
# Second Region Range (tensor(-0.1747), tensor(2.2595))
# Layer Name: wi
# Local minimum:  tensor(-21.3750)  Local max:  tensor(18.) Points:  500
# Ratio of first region range coverage: tensor(0.1827) Region of selection index:  1
# Ratio of second region range coverage: tensor(0.0643) Region of selection index:  0
# First Region Range:  (tensor(-10.0912), tensor(-7.5661))
# Second Region Range (tensor(-3.9364), tensor(3.2442))
# Layer Name: wo
# Local minimum:  tensor(-14.1875)  Local max:  tensor(9.0625) Points:  500
# Ratio of first region range coverage: tensor(0.1847) Region of selection index:  3
# Ratio of second region range coverage: tensor(0.0442) Region of selection index:  0
# First Region Range:  (tensor(-14.1875), tensor(-13.1624))
# Second Region Range (tensor(-2.7722), tensor(1.5144))
# Layer Name: q
# Local minimum:  tensor(-0.3398)  Local max:  tensor(0.4395) Points:  500
# Ratio of first region range coverage: tensor(0.2791) Region of selection index:  1
# Ratio of second region range coverage: tensor(0.1586) Region of selection index:  2
# First Region Range:  (tensor(-0.2258), tensor(-0.0088))
# Second Region Range (tensor(0.0084), tensor(0.1318))
# Layer Name: k
# Local minimum:  tensor(-3.1719)  Local max:  tensor(3.0781) Points:  500
# Ratio of first region range coverage: tensor(0.3554) Region of selection index:  1
# Ratio of second region range coverage: tensor(0.1486) Region of selection index:  2
# First Region Range:  (tensor(-2.2701), tensor(-0.0531))
# Second Region Range (tensor(0.4604), tensor(1.3872))
# Layer Name: v
# Local minimum:  tensor(-5.)  Local max:  tensor(4.9062) Points:  500
# Ratio of first region range coverage: tensor(0.3514) Region of selection index:  2
# Ratio of second region range coverage: tensor(0.1245) Region of selection index:  5
# First Region Range:  (tensor(-3.6501), tensor(-0.1759))
# Second Region Range (tensor(1.8689), tensor(3.0997))
# Layer Name: o
# Local minimum:  tensor(-21.7500)  Local max:  tensor(22.8750) Points:  500
# Ratio of first region range coverage: tensor(0.3092) Region of selection index:  7
# Ratio of second region range coverage: tensor(0.0482) Region of selection index:  0
# First Region Range:  (tensor(-19.3354), tensor(-17.1891))
# Second Region Range (tensor(-9.0511), tensor(4.7209))
# Layer Name: q
# Local minimum:  tensor(-0.2793)  Local max:  tensor(0.2637) Points:  500
# Ratio of first region range coverage: tensor(0.2691) Region of selection index:  2
# Ratio of second region range coverage: tensor(0.2229) Region of selection index:  3
# First Region Range:  (tensor(-0.1835), tensor(-0.0377))
# Second Region Range (tensor(0.0069), tensor(0.1277))
# Layer Name: k
# Local minimum:  tensor(-4.6562)  Local max:  tensor(4.5625) Points:  500
# Ratio of first region range coverage: tensor(0.2309) Region of selection index:  3
# Ratio of second region range coverage: tensor(0.1506) Region of selection index:  5
# First Region Range:  (tensor(-2.3839), tensor(-0.2593))
# Second Region Range (tensor(-0.0746), tensor(1.3110))
# Layer Name: v
# Local minimum:  tensor(-5.0625)  Local max:  tensor(6.5938) Points:  500
# Ratio of first region range coverage: tensor(0.3133) Region of selection index:  3
# Ratio of second region range coverage: tensor(0.1727) Region of selection index:  4
# First Region Range:  (tensor(-3.9413), tensor(-0.2972))
# Second Region Range (tensor(0.4269), tensor(2.4358))
# Layer Name: o
# Local minimum:  tensor(-10.0625)  Local max:  tensor(13.5625) Points:  500
# Ratio of first region range coverage: tensor(0.1526) Region of selection index:  3
# Ratio of second region range coverage: tensor(0.1406) Region of selection index:  2
# First Region Range:  (tensor(-3.9077), tensor(-0.5936))
# Second Region Range (tensor(-0.2148), tensor(3.3834))
# Layer Name: wi
# Local minimum:  tensor(-8.6875)  Local max:  tensor(8.5625) Points:  500
# Ratio of first region range coverage: tensor(0.1506) Region of selection index:  0
# Ratio of second region range coverage: tensor(0.1446) Region of selection index:  1
# First Region Range:  (tensor(-3.0873), tensor(-0.4946))
# Second Region Range (tensor(-0.1144), tensor(2.3746))
# Layer Name: wo
# Local minimum:  tensor(-10.0625)  Local max:  tensor(10.6875) Points:  500
# Ratio of first region range coverage: tensor(0.2149) Region of selection index:  3
# Ratio of second region range coverage: tensor(0.0482) Region of selection index:  0
# First Region Range:  (tensor(-8.1081), tensor(-7.1101))
# Second Region Range (tensor(-2.9102), tensor(1.5392))
# Layer Name: q
# Local minimum:  tensor(-0.3066)  Local max:  tensor(0.3242) Points:  500
# Ratio of first region range coverage: tensor(0.2811) Region of selection index:  2
# Ratio of second region range coverage: tensor(0.0964) Region of selection index:  3
# First Region Range:  (tensor(-0.1802), tensor(-0.0032))
# Second Region Range (tensor(0.0587), tensor(0.1194))
# Layer Name: k
# Local minimum:  tensor(-2.7031)  Local max:  tensor(2.4375) Points:  500
# Ratio of first region range coverage: tensor(0.2952) Region of selection index:  2
# Ratio of second region range coverage: tensor(0.2209) Region of selection index:  3
# First Region Range:  (tensor(-1.7348), tensor(-0.2204))
# Second Region Range (tensor(0.0372), tensor(1.1704))
# Layer Name: v
# Local minimum:  tensor(-5.8750)  Local max:  tensor(4.4062) Points:  500
# Ratio of first region range coverage: tensor(0.3594) Region of selection index:  0
# Ratio of second region range coverage: tensor(0.1566) Region of selection index:  1
# First Region Range:  (tensor(-3.8146), tensor(-0.1266))
# Second Region Range (tensor(0.5534), tensor(2.1604))
# Layer Name: o
# Local minimum:  tensor(-48.5000)  Local max:  tensor(37.5000) Points:  500
# Ratio of first region range coverage: tensor(0.4799) Region of selection index:  2
# Ratio of second region range coverage: tensor(0.0141) Region of selection index:  5
# First Region Range:  (tensor(-24.8888), tensor(16.3016))
# Second Region Range (tensor(25.7806), tensor(26.9870))
# Layer Name: q
# Local minimum:  tensor(-0.2559)  Local max:  tensor(0.2715) Points:  500
# Ratio of first region range coverage: tensor(0.4177) Region of selection index:  1
# Ratio of second region range coverage: tensor(0.2008) Region of selection index:  2
# First Region Range:  (tensor(-0.2326), tensor(-0.0128))
# Second Region Range (tensor(0.0527), tensor(0.1584))
# Layer Name: k
# Local minimum:  tensor(-5.6562)  Local max:  tensor(6.3438) Points:  500
# Ratio of first region range coverage: tensor(0.2329) Region of selection index:  3
# Ratio of second region range coverage: tensor(0.1426) Region of selection index:  4
# First Region Range:  (tensor(-3.0350), tensor(-0.2454))
# Second Region Range (tensor(-0.0771), tensor(1.6303))
# Layer Name: v
# Local minimum:  tensor(-8.2500)  Local max:  tensor(7.7500) Points:  500
# Ratio of first region range coverage: tensor(0.3835) Region of selection index:  0
# Ratio of second region range coverage: tensor(0.1004) Region of selection index:  3
# First Region Range:  (tensor(-6.9033), tensor(-0.7791))
# Second Region Range (tensor(1.8502), tensor(3.4534))
# Layer Name: o
# Local minimum:  tensor(-25.5000)  Local max:  tensor(21.) Points:  500
# Ratio of first region range coverage: tensor(0.2972) Region of selection index:  5
# Ratio of second region range coverage: tensor(0.0161) Region of selection index:  4
# First Region Range:  (tensor(-8.9128), tensor(-8.1673))
# Second Region Range (tensor(-7.9810), tensor(5.8106))
# Layer Name: wi
# Local minimum:  tensor(-10.6250)  Local max:  tensor(10.5000) Points:  500
# Ratio of first region range coverage: tensor(0.2651) Region of selection index:  0
# Ratio of second region range coverage: tensor(0.) Region of selection index:  1
# First Region Range:  (tensor(-3.3011), tensor(2.2871))
# Second Region Range (tensor(2.3717), tensor(2.3717))
# Layer Name: wo
# Local minimum:  tensor(-16.2500)  Local max:  tensor(10.5000) Points:  500
# Ratio of first region range coverage: tensor(0.2129) Region of selection index:  5
# Ratio of second region range coverage: tensor(0.0261) Region of selection index:  1
# First Region Range:  (tensor(-9.2275), tensor(-8.5306))
# Second Region Range (tensor(-3.7059), tensor(1.9765))
# Layer Name: q
# Local minimum:  tensor(-0.2617)  Local max:  tensor(0.2852) Points:  500
# Ratio of first region range coverage: tensor(0.2992) Region of selection index:  0
# Ratio of second region range coverage: tensor(0.2149) Region of selection index:  2
# First Region Range:  (tensor(-0.1982), tensor(-0.0349))
# Second Region Range (tensor(0.0057), tensor(0.1230))
# Layer Name: k
# Local minimum:  tensor(-3.5000)  Local max:  tensor(2.3281) Points:  500
# Ratio of first region range coverage: tensor(0.2831) Region of selection index:  0
# Ratio of second region range coverage: tensor(0.1225) Region of selection index:  1
# First Region Range:  (tensor(-1.6897), tensor(-0.0428))
# Second Region Range (tensor(0.4711), tensor(1.1835))
# Layer Name: v
# Local minimum:  tensor(-4.5312)  Local max:  tensor(5.9688) Points:  500
# Ratio of first region range coverage: tensor(0.3454) Region of selection index:  1
# Ratio of second region range coverage: tensor(0.1787) Region of selection index:  2
# First Region Range:  (tensor(-4.0894), tensor(-0.4701))
# Second Region Range (tensor(0.2663), tensor(2.1391))
# Layer Name: o
# Local minimum:  tensor(-42.7500)  Local max:  tensor(45.7500) Points:  500
# Ratio of first region range coverage: tensor(0.2450) Region of selection index:  3
# Ratio of second region range coverage: tensor(0.0582) Region of selection index:  0
# First Region Range:  (tensor(-32.2861), tensor(-27.1428))
# Second Region Range (tensor(-20.4033), tensor(1.2340))
# Layer Name: q
# Local minimum:  tensor(-0.2334)  Local max:  tensor(0.2188) Points:  500
# Ratio of first region range coverage: tensor(0.3755) Region of selection index:  1
# Ratio of second region range coverage: tensor(0.1024) Region of selection index:  3
# First Region Range:  (tensor(-0.1736), tensor(-0.0042))
# Second Region Range (tensor(0.0665), tensor(0.1127))
# Layer Name: k
# Local minimum:  tensor(-5.0312)  Local max:  tensor(4.7188) Points:  500
# Ratio of first region range coverage: tensor(0.2390) Region of selection index:  1
# Ratio of second region range coverage: tensor(0.1606) Region of selection index:  2
# First Region Range:  (tensor(-2.5498), tensor(-0.2246))
# Second Region Range (tensor(-0.1074), tensor(1.4557))
# Layer Name: v
# Local minimum:  tensor(-12.3125)  Local max:  tensor(10.8125) Points:  500
# Ratio of first region range coverage: tensor(0.3835) Region of selection index:  0
# Ratio of second region range coverage: tensor(0.0843) Region of selection index:  2
# First Region Range:  (tensor(-9.7637), tensor(-0.9122))
# Second Region Range (tensor(2.4245), tensor(4.3709))
# Layer Name: o
# Local minimum:  tensor(-20.5000)  Local max:  tensor(19.2500) Points:  500
# Ratio of first region range coverage: tensor(0.1466) Region of selection index:  10
# Ratio of second region range coverage: tensor(0.1365) Region of selection index:  8
# First Region Range:  (tensor(-6.4800), tensor(-1.0631))
# Second Region Range (tensor(-0.4259), tensor(5.3893))
# Layer Name: wi
# Local minimum:  tensor(-13.6875)  Local max:  tensor(10.2500) Points:  500
# Ratio of first region range coverage: tensor(0.1787) Region of selection index:  0
# Ratio of second region range coverage: tensor(0.1305) Region of selection index:  1
# First Region Range:  (tensor(-4.5730), tensor(-0.3036))
# Second Region Range (tensor(-0.1597), tensor(2.9584))
# Layer Name: wo
# Local minimum:  tensor(-45.2500)  Local max:  tensor(24.5000) Points:  500
# Ratio of first region range coverage: tensor(0.0904) Region of selection index:  4
# Ratio of second region range coverage: tensor(0.0803) Region of selection index:  1
# First Region Range:  (tensor(-11.7029), tensor(-6.1117))
# Second Region Range (tensor(-3.7355), tensor(2.5546))
# Layer Name: lm_head
# Local minimum:  tensor(-792.)  Local max:  tensor(348.) Points:  500
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # **OUTLIER TRAINING**

# %%
from outlier_training.convertQuantizeModel_OutlierTraining import convertDenseLayer

from datasets import load_dataset
from torch.utils.data import Dataset, DataLoader
from torch.optim import Adam
from torch.nn import CrossEntropyLoss

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
path = 'ClassificationReport.txt'

# %%
class TextDataset(Dataset):
    def __init__(self, data):
        texts, labels = data
        self.texts = texts
        self.labels = labels

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        label = self.labels[idx]
        return text, label

# %%
class SimpleClassifier(nn.Module):
    def __init__(self, input_size, output_classes):
        super(SimpleClassifier, self).__init__()
        self.fc1 = nn.Linear(input_size, 128)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(128, 64)
        self.relu2 = nn.ReLU()
        self.fc3 = nn.Linear(64, output_classes)
        self.sig = nn.Sigmoid()
        
    def forward(self, x):
        out = self.fc1(x)
        out = self.relu1(out)
        out = self.fc2(out)
        out = self.relu2(out)
        out = self.fc3(out)
        out = self.sig(out)

        return out

# %% [markdown]
# ## **BERT BASE MODEL TESTING**

# %% [markdown]
# ### **DATASET LOADING**

# %%
dataset = load_dataset("glue", "sst2")
train_sentences, train_labels = dataset["train"]["sentence"], dataset["train"]["label"]
test_sentences, test_labels = dataset["validation"]["sentence"], dataset["validation"]["label"]
unique_class_count = len(set(train_labels))

train_dataset = TextDataset(data=(train_sentences, train_labels))
test_dataset = TextDataset(data=(test_sentences, test_labels))

train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=32)

# %% [markdown]
# ### **SAVING MODEL**

# %%
from transformers import BertTokenizer, BertModel

# Load pre-trained BERT tokenizer and model
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased').to(device)

# Saving the model
# torch.save(model, f"../../saved/bert-base-uncased/bert-base-uncased.pt")

# del model

# %%
sentences = ["This is good","this is too bad","this is fine","How can That go wrong"]

Tokenised_Sentence = tokenizer(sentences, max_length=512, padding='max_length', return_tensors='pt')

Tokenised_Sentence.to(device)
Output = model(**Tokenised_Sentence)
Embeddings_Output = torch.sum(Output.last_hidden_state, dim= 1)

del model

# %%
Embeddings_Output
# Out:
# torch.Size([4, 768])

# %%
model = torch.load('../../saved/bert-base-uncased/bert-base-uncased-quant.pt')
sentences = ["This is good","this is too bad","this is fine","How can That go wrong"]

Tokenised_Sentence = tokenizer(sentences, max_length=512, padding='max_length', return_tensors='pt')

Tokenised_Sentence
Output = model(**Tokenised_Sentence)
Embeddings_Output_quant = torch.sum(Output.last_hidden_state, dim= 1)

del model

# %%
print(Embeddings_Output[0,:])
print(Embeddings_Output_quant[0,:])
# Out:
# tensor([-8.2479e+01, -1.1345e+02,  1.1523e+02,  9.6232e+00,  4.6548e+01,
#          6.5042e+01,  5.3600e+01,  1.6288e+02,  9.1292e+01, -3.0552e+02,
#         -4.1840e+01,  9.1445e+01,  1.3136e+02,  1.8263e+02,  7.2633e+01,
#          1.0237e+02,  1.5599e+02,  2.2578e+02,  2.4568e+01,  7.8412e+01,
#         -7.1214e+01, -1.4519e+02,  1.3365e+01, -8.7482e+01,  2.1157e+02,
#          9.9785e+01, -1.5848e+02, -2.3635e+01, -4.6831e+01,  2.2749e+01,
#          3.8513e+01, -1.5347e+02,  1.1719e+02,  4.2451e+01, -8.9812e+00,
#         -6.2050e+01, -1.8140e+02, -7.9907e+01, -2.2877e+02, -5.0162e+01,
#          5.4086e+01, -1.1202e+02,  1.0069e+02, -1.9310e+02, -1.3141e+02,
#         -2.1523e+01, -1.9445e+02,  6.3946e+01, -2.1452e+02, -1.8621e+02,
#          1.0916e+01,  9.1653e+00, -6.5905e+01,  3.4745e+01, -3.9024e+01,
#         -1.9638e+01, -5.2824e+01, -2.3210e+01, -2.0746e+02, -1.6731e+02,
#          1.1897e+02, -1.3113e+02,  1.8684e+02, -4.5105e+01, -2.4873e+01,
#         -3.1907e+01,  2.7283e+02, -8.4907e+01, -6.9638e+01,  9.1262e+01,
#         -6.3275e+01, -1.3992e+02, -5.8594e+01, -1.4971e+02,  1.4299e+02,
#          4.8956e+00,  1.6623e+01, -3.9799e+01, -1.3456e+00, -4.5031e+01,
#          4.6737e+01,  2.4707e+01, -5.3965e+01,  2.2441e+02, -1.7394e+02,
#          4.7853e+01,  4.5694e+00,  9.2502e+01, -6.0740e+01,  1.1423e+02,
#         -2.3266e+01, -5.4059e+01,  5.3914e+01,  2.8787e+01,  1.3651e+02,
#         -3.0196e+02, -1.0550e+02, -8.2479e+00, -1.1248e+02, -1.5274e+02,
#         -3.8834e+01, -2.9696e+02, -6.5025e+01,  1.1170e+00, -1.6440e+02,
#         -5.1993e+01, -4.7395e+01, -2.9268e+02,  6.1097e+01, -1.2824e+01,
#         -5.9476e+02, -2.4068e+02,  3.6582e+02,  2.5896e+02, -1.9791e+02,
#          1.7191e+02, -2.7842e+02, -1.2734e+02, -3.5675e+02,  2.7860e+02,
#         -2.3838e+02, -2.6558e+02,  3.4514e+01,  7.2451e+00, -1.5228e+02,
#          8.1299e+02, -6.6321e+02,  6.4031e+01,  6.3127e+01,  7.5247e+02,
#         -1.1964e+02, -1.4194e+02,  3.1190e+02, -1.9393e+02,  3.9935e+02,
#         -3.0007e+02,  1.0182e+02, -3.7296e+02, -2.1156e+02, -1.3453e+02,
#          2.8387e+02,  3.1057e+02,  3.0142e+02,  2.3150e+02, -2.8405e+02,
#         -5.7287e+02, -4.1964e+02, -3.8777e+02, -3.0461e+02,  3.6502e+02,
#          1.9765e+02, -1.2630e+02,  3.0127e+02,  2.3904e+02, -3.5590e+02,
#         -3.2006e+01, -2.1333e+02,  3.2595e+01, -2.3975e+02, -1.9895e+01,
#          7.0695e+01,  4.0652e+02,  4.0259e+02, -1.0304e+02,  2.8717e+01,
#         -6.0411e+01, -5.4727e+02,  7.5809e+01,  6.4954e+02, -1.0626e+02,
#         -3.9181e+02,  6.0706e+01,  2.2580e+00, -1.0051e+02,  3.2274e+01,
#          3.6791e+02,  2.3596e+02,  5.2903e+01,  1.5666e+02,  2.3445e+02,
#         -2.8635e+02,  9.9744e+01, -1.6932e+02,  2.3679e+01,  6.8966e+01,
#         -1.2429e+02,  4.2623e+02, -3.9171e+02,  4.2927e+02,  2.3854e+02,
#          9.2925e+00,  2.6101e+02, -1.5475e+02, -5.8467e+01, -1.0543e+02,
#         -2.8249e-01,  2.0360e+02, -2.7753e+02,  1.6091e+02,  2.6276e+02,
#          4.1771e+02, -5.8126e+00,  5.4519e+01,  2.0044e+02, -9.0301e+01,
#         -5.2157e+02,  8.9580e+01, -5.5712e+02,  2.7012e+02, -6.2581e+02,
#         -1.2801e+02, -4.4833e+02, -7.1298e+02, -3.3849e+02,  1.7165e+02,
#          4.8161e+02,  2.7758e+02,  2.4777e+02, -2.8073e+02, -5.9551e+01,
#          6.0482e+01, -6.9230e+01, -2.0296e+01], grad_fn=<SliceBackward0>)

# %% [markdown]
# ### **FINE TUNING MODEL**

# %%
Token_max_length = 512

# Pretrained model weights
Pretrained_model = torch.load(f"../../saved/bert-base-uncased/bert-base-uncased.pt").to(device)

# Classifier Model
Classifier_model = SimpleClassifier(input_size=768, output_classes=unique_class_count).to(device)

optimizer = Adam(Classifier_model.parameters(), lr=5e-3)
loss_fn = CrossEntropyLoss()

EpochCycle = 5

# %% [markdown]
# #### **TRAINING THE CLASSIFIER WITH THE ORIGINAL MODEL**

# %%
for epoch in range(EpochCycle): 
    
    running_loss = 0.0
    correct = 0
    total = 0

    for text, labels in train_dataloader:
        optimizer.zero_grad()

        Tokenised_Sentence = tokenizer(text, max_length=512, padding='max_length', return_tensors='pt')

        Tokenised_Sentence.to(device)
        Output = Pretrained_model(**Tokenised_Sentence)
        Embeddings_Output = torch.sum(Output.last_hidden_state, dim= 1)

        Classifier_output = Classifier_model(Embeddings_Output)
        Prediction = torch.argmax(Classifier_output, dim = 1 )
        Loss = loss_fn(Prediction.to(torch.float64).to(device), labels.to(torch.float64).to(device))

        Loss.backward()
        optimizer.step()

        running_loss += Loss.item()
        total += labels.size(0)
        correct += (Prediction == labels).sum().item()

    print('Epoch:', epoch+1)
    print('Training Loss:', running_loss / len(train_dataloader))
    print('Training Accuracy:', correct / total)

# %% [markdown]
# #### **INFERENCE OF ORIGINAL MODEL**

# %%
y_pred_test = []
y_actual_test = []

with torch.no_grad():

    for text, labels in tqdm(train_dataloader):
        
        Tokenised_Sentence = tokenizer(text, max_length=512, padding='max_length', return_tensors='pt')

        Tokenised_Sentence.to(device)
        Output = Pretrained_model(**Tokenised_Sentence)
        Embeddings_Output = torch.sum(Output.last_hidden_state, dim= 1)

        Classifier_output = Classifier_model(Embeddings_Output)
        Prediction = torch.argmax(Classifier_output, dim = 1 )

        y_pred_test.extend(Prediction.tolist())
        y_actual_test.extend(labels.tolist())


report = classification_report(y_actual_test, y_pred_test)

# Save the classification report to a text file
with open(path, 'w') as f:
    f.write(report)

print("Classification report saved to 'classification_report.txt'")

# %% [markdown]
# #### **QUANTISING PRETRAINED MODEL**

# %%
QuantOutlierModel = convertDenseLayer(Classifier_model.to('cpu'))
Outliers_optimizer = Adam(QuantOutlierModel.parameters(), lr=5e-3)

# %% [markdown]
# #### **TRAINING THE OUTLIERS**

# %%
for epoch in range(EpochCycle): 
    
    running_loss = 0.0
    correct = 0
    total = 0

    for text, labels in train_dataloader:
        Outliers_optimizer.zero_grad()

        Tokenised_Sentence = tokenizer(text, max_length=512, padding='max_length', return_tensors='pt')

        Tokenised_Sentence.to(device)
        Output = QuantOutlierModel(**Tokenised_Sentence)
        Embeddings_Output = torch.sum(Output.last_hidden_state, dim= 1)

        Classifier_output = Classifier_model(Embeddings_Output)
        Prediction = torch.argmax(Classifier_output, dim = 1 )
        Loss = loss_fn(Prediction.to(torch.float64).to(device), labels.to(torch.float64).to(device))

        Loss.backward()
        Outliers_optimizer.step()

        running_loss += Loss.item()
        total += labels.size(0)
        correct += (Prediction == labels).sum().item()

    print('Epoch:', epoch+1)
    print('Training Loss:', running_loss / len(train_dataloader))
    print('Training Accuracy:', correct / total)
# Out:
# fc1.bias Parameter containing:
# tensor([-0.0184,  0.0301,  0.0318, -0.0023,  0.0095,  0.0294, -0.0123,  0.0087,
#         -0.0068, -0.0308,  0.0152,  0.0276,  0.0290, -0.0298, -0.0064,  0.0207,
#          0.0358,  0.0079, -0.0260,  0.0202,  0.0170, -0.0168,  0.0208, -0.0097,
#         -0.0097, -0.0307, -0.0105, -0.0129,  0.0314, -0.0333, -0.0006, -0.0231,
#          0.0106, -0.0028, -0.0287,  0.0246,  0.0290,  0.0107, -0.0234,  0.0271,
#          0.0093, -0.0074,  0.0165,  0.0230, -0.0081, -0.0196, -0.0060,  0.0273,
#          0.0019, -0.0320,  0.0112,  0.0030,  0.0291,  0.0021, -0.0207, -0.0196,
#          0.0215, -0.0155, -0.0175, -0.0025, -0.0048,  0.0341,  0.0038,  0.0083,
#         -0.0222,  0.0306,  0.0338, -0.0004, -0.0006,  0.0338,  0.0021, -0.0079,
#          0.0160,  0.0148, -0.0337, -0.0118, -0.0175,  0.0138, -0.0206,  0.0233,
#         -0.0015, -0.0262, -0.0018, -0.0139, -0.0102,  0.0233,  0.0070,  0.0087,
#          0.0009, -0.0143, -0.0325, -0.0066, -0.0136,  0.0192, -0.0071, -0.0076,
#         -0.0077, -0.0267,  0.0213,  0.0230,  0.0050,  0.0040, -0.0339,  0.0095,
#         -0.0046,  0.0351, -0.0229,  0.0187,  0.0181, -0.0292,  0.0233, -0.0302,
#          0.0316,  0.0194,  0.0150, -0.0008, -0.0245, -0.0315, -0.0212, -0.0029,
#          0.0130, -0.0133, -0.0303,  0.0301,  0.0194,  0.0126, -0.0209,  0.0212],
#        requires_grad=True)
# fc1.Updates Parameter containing:
# tensor([[-5.2755e-03, -4.7960e-03,  9.1966e-03,  ...,  4.6128e-03,
#           6.3750e-03,  8.7207e-04],
#         [-4.7116e-03, -2.1153e-03,  1.2243e-03,  ..., -2.7909e-03,
#          -4.8300e-03,  4.1928e-03],
#         [ 2.0429e-03,  7.9017e-04,  2.6966e-03,  ...,  1.5431e-02,
#           7.0541e-03, -2.3002e-02],
#         ...,
#         [ 2.8261e-03, -1.7166e-02,  1.1138e-02,  ...,  4.7963e-03,
#          -1.9730e-02,  2.6107e-03],
#         [-2.6383e-05, -1.5377e-02, -2.6973e-04,  ...,  9.0140e-03,
#          -9.5232e-03, -2.0310e-02],
#         [ 1.1383e-03,  2.9070e-03,  2.2091e-03,  ..., -3.0231e-03,
#           1.0988e-02, -1.5153e-02]], requires_grad=True)
# fc2.bias Parameter containing:
# tensor([ 0.0312,  0.0368, -0.0663,  0.0778, -0.0039, -0.0871,  0.0604,  0.0330,
#          0.0826,  0.0300, -0.0436, -0.0836, -0.0707,  0.0725, -0.0213,  0.0661,
#         -0.0510, -0.0303, -0.0288, -0.0037, -0.0133,  0.0087, -0.0328, -0.0798,
#         -0.0645,  0.0005, -0.0722,  0.0769,  0.0224,  0.0455,  0.0612,  0.0712,
#         -0.0532,  0.0484,  0.0325, -0.0191, -0.0207, -0.0372,  0.0819,  0.0743,
#         -0.0093,  0.0122, -0.0010, -0.0701,  0.0502,  0.0044,  0.0871,  0.0753,
#         -0.0590, -0.0568,  0.0677, -0.0082,  0.0649, -0.0209,  0.0179, -0.0497,
#          0.0404, -0.0637,  0.0312,  0.0114,  0.0143, -0.0823, -0.0057, -0.0500],
#        requires_grad=True)
# fc2.Updates Parameter containing:
# tensor([[ 0.0323, -0.0355,  0.0039,  ...,  0.0230, -0.0522,  0.0228],
#         [-0.0077, -0.0303, -0.0422,  ...,  0.0306,  0.0283, -0.0503],
#         [ 0.0131,  0.0125,  0.0284,  ...,  0.0031, -0.0155,  0.0404],
#         ...,
#         [-0.0318,  0.0219,  0.0160,  ..., -0.0129,  0.0153,  0.0015],
#         [ 0.0117, -0.0521,  0.0193,  ..., -0.0008,  0.0460,  0.0318],
#         [-0.0388, -0.0398, -0.0009,  ...,  0.0016, -0.0415,  0.0011]],
#        requires_grad=True)
# fc3.bias Parameter containing:
# tensor([-0.0576,  0.0827], requires_grad=True)
# fc3.Updates Parameter containing:
# tensor([[-0.0331,  0.0199, -0.0009, -0.0170,  0.0159,  0.0279,  0.0557,  0.0318,
#          -0.0037, -0.0018, -0.0315, -0.0757, -0.0256,  0.0022,  0.0343, -0.0502,
#           0.0405, -0.0407,  0.0330, -0.0147, -0.0471, -0.0046,  0.0480, -0.0005,
#           0.0470, -0.0377, -0.0035, -0.0450, -0.0692, -0.0177, -0.0090,  0.0219,
#           0.0256,  0.0007,  0.0305,  0.0627,  0.0050, -0.0182, -0.0700,  0.0309,
#          -0.0374, -0.0118,  0.0447,  0.0005,  0.0059,  0.0590,  0.0215,  0.0007,
#          -0.0684,  0.0183,  0.0552,  0.0132, -0.0117,  0.0599,  0.0421, -0.0688,
#           0.0478, -0.0607,  0.0261, -0.0146,  0.0206,  0.0149, -0.0270, -0.0173],
#         [-0.0599,  0.0038,  0.0289,  0.0343, -0.0418,  0.0113, -0.0576, -0.0038,
#          -0.0020,  0.0054, -0.0032, -0.0107,  0.0214,  0.0077,  0.0049,  0.0018,
#          -0.0686,  0.0378,  0.0277,  0.0032,  0.0525,  0.0275,  0.0299,  0.0241,
#          -0.0496, -0.0072, -0.0717,  0.0462, -0.0037, -0.0392, -0.0584, -0.0441,
#          -0.0166,  0.0390, -0.0218, -0.0292,  0.0041,  0.0239,  0.0359,  0.0351,
#          -0.0651, -0.0029,  0.0008, -0.0141,  0.0275,  0.0334, -0.0717,  0.0029,
#          -0.0032,  0.0039,  0.0260, -0.0524, -0.0025, -0.0081, -0.0085, -0.0067,
#          -0.0291, -0.0065, -0.0034, -0.0154,  0.0365, -0.0401,  0.0153, -0.0015]],
#        requires_grad=True)

# %% [markdown]
# #### **INFERENCE OF QUANTISED MODEL**

# %%
y_pred_test = []
y_actual_test = []

with torch.no_grad():

    for text, labels in tqdm(train_dataloader):
        
        Tokenised_Sentence = tokenizer(text, max_length=512, padding='max_length', return_tensors='pt')

        Tokenised_Sentence.to(device)
        Output = QuantOutlierModel(**Tokenised_Sentence)
        Embeddings_Output = torch.sum(Output.last_hidden_state, dim= 1)

        Classifier_output = Classifier_model(Embeddings_Output)
        Prediction = torch.argmax(Classifier_output, dim = 1 )

        y_pred_test.extend(Prediction.tolist())
        y_actual_test.extend(labels.tolist())


report = classification_report(y_actual_test, y_pred_test)

# Save the classification report to a text file
with open(path, 'w') as f:
    f.write(report)

print("Classification report saved to 'classification_report.txt'")

# %%
models = ["bert-base-uncased-quant.pt","bert-base-uncased-quant"]
for model in models:
    if "pt" in model:
        TestModel = torch.load(model)
        modelName = model.split("/")[-1].split(".")[0]
    else:
        TestModel = BertModel.from_pretrained(model)
        modelName = model
    tokenizer = BertTokenizer.from_pretrained(f'bert-{"base" if "base" in model else "large"}-uncased')
    tokenized_sentences = tokenizer(sentences, pad_to_max_length = True,max_length=512, return_tensors="pt")
    with torch.no_grad():
        outputs = TestModel(**tokenized_sentences)
        embeddings = outputs.last_hidden_state[:, 0, :]
    embeddings = embeddings.numpy()
    print(embeddings)
